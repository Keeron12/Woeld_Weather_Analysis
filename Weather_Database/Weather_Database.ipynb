# %%
# Use the citipy module to determine city based on latitude and longitude

from citipy import citipy

# Import the time module

import time

# Import the requests library

import requests


# Import the API key

from config import weather_api_key

# Import the datetime module from the datetime library

from datetime import datetime

# Imports

import pandas as pd

import timeit

import random

import numpy as np

# %%
# Create a set of random latitude and longitude combinations

lats = np.random.uniform(low=-90.000, high=90.000, size=2000)

lngs = np.random.uniform(low=-180.00, high=180.00, size=2000)

lat_lngs = zip(lats, lngs)

lat_lngs

# %%
# Starting URL for WWeather Map API Call

url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Open the zip to query

coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.

cities = []

# Identify the nearest city for each latitude and longitude combination.

for coordinate in coordinates:
    
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    
    if city not in cities:
        
        cities.append(city)
        
# Print the city count to confirm sufficient count.

len(cities)
# Out:
# 732

# %%
# Create an empty list to hold the weather data

city_data = []

# Print the beginning of the logging 

print("Beginning Data Retrieval      ")

print("----------------------------")





# Create counter

record_count = 1

set_count = 1



# Loop through all the cities in the list.
for i, city in enumerate(cities):
    
    
    # Group cities in sets of 50 for logging purposes
    
    if (i % 50 == 0 and i >=50):
        
        set_count += 1
        
        record_count = 1
        
        time.sleep(60)
        
    # Create endpoint URL with each city.
    
    city_url = url + "&q=" + city.replace(" ","+")
    
    
    # Log the URL, record, and set numbers and the city
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count
    
    record_count += 1
    
    # Run an API request for each of the cities.
    
    try:
        
        # Parse the JSON and retrieve data.
        
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        
        city_lat = city_weather["coord"]["lat"]
        
        city_lng = city_weather["coord"]["lon"]
        
        city_max_temp = city_weather["main"]["temp_max"]
        
        city_humidity = city_weather["main"]["humidity"]
        
        city_clouds = city_weather["clouds"]["all"]
        
        city_wind = city_weather["wind"]["speed"]
        
        city_country = city_weather["sys"]["country"]
        
        city_description = city_weather['weather'][0]['description']
        
        
        # Append the city information into city_data list.
        
        city_data.append({"City": city.title(),
                          
                          "Lat": city_lat,
                          
                          "Lng": city_lng,
                          
                          "Max Temp": city_max_temp,
                          
                          "Humidity": city_humidity,
                          
                          "Cloudiness": city_clouds,
                          
                          "Wind Speed": city_wind,
                          
                          "Country": city_country,
                          
                          "Current Description": city_description})

# If an error is experienced, skip the city.

    except:
        
        print("City not found. Skipping...")
        
        pass

# Indicate that Data Loading is complete.

print("-----------------------------")

print("Data Retrieval Complete      ")

print("-----------------------------")
# Out:
# Beginning Data Retrieval
# ----------------------------
# Processing Record 1 of Set 1 | saskylakh
# Processing Record 2 of Set 1 | saint-gaudens
# Processing Record 3 of Set 1 | yellowknife
# Processing Record 4 of Set 1 | general roca
# Processing Record 5 of Set 1 | poplar bluff
# Processing Record 6 of Set 1 | kapaa
# Processing Record 7 of Set 1 | kahului
# Processing Record 8 of Set 1 | udachnyy
# Processing Record 9 of Set 1 | christchurch
# Processing Record 10 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 11 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | asau
# Processing Record 14 of Set 1 | punta arenas
# Processing Record 15 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 16 of Set 1 | neringa
# Processing Record 17 of Set 1 | upernavik
# Processing Record 18 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | hay river
# Processing Record 21 of Set 1 | buala
# Processing Record 22 of Set 1 | solnechnyy
# Processing Record 23 of Set 1 | castro
# Processing Record 24 of Set 1 | longyearbyen
# Processing Record 25 of Set 1 | mahebourg
# Processing Record 26 of Set 1 | bluff
# Processing Record 27 of Set 1 | uarini
# Processing Record 28 of Set 1 | hamilton
# Processing Record 29 of Set 1 | busselton
# Processing Record 30 of Set 1 | komsomolskiy
# Processing Record 31 of Set 1 | zhezkazgan
# Processing Record 32 of Set 1 | mataura
# Processing Record 33 of Set 1 | umm lajj
# Processing Record 34 of Set 1 | omama
# Processing Record 35 of Set 1 | kodiak
# Processing Record 36 of Set 1 | jamestown
# Processing Record 37 of Set 1 | mezhdurechensk
# Processing Record 38 of Set 1 | vaini
# Processing Record 39 of Set 1 | dawlatabad
# Processing Record 40 of Set 1 | vaasa
# Processing Record 41 of Set 1 | itarema
# Processing Record 42 of Set 1 | barbate
# Processing Record 43 of Set 1 | east london
# Processing Record 44 of Set 1 | tazovskiy
# Processing Record 45 of Set 1 | atuona
# Processing Record 46 of Set 1 | oliveira do hospital
# Processing Record 47 of Set 1 | kiruna
# Processing Record 48 of Set 1 | kokoda
# Processing Record 49 of Set 1 | alexandria
# Processing Record 50 of Set 1 | avarua
# Processing Record 1 of Set 2 | petropavlovsk-kamchatskiy
# Processing Record 2 of Set 2 | port alfred
# Processing Record 3 of Set 2 | leningradskiy
# Processing Record 4 of Set 2 | rincon
# Processing Record 5 of Set 2 | srednekolymsk
# Processing Record 6 of Set 2 | barrow
# Processing Record 7 of Set 2 | chuy
# Processing Record 8 of Set 2 | khatanga
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | port elizabeth
# Processing Record 11 of Set 2 | san cristobal
# Processing Record 12 of Set 2 | bathsheba
# Processing Record 13 of Set 2 | peniche
# Processing Record 14 of Set 2 | flinders
# Processing Record 15 of Set 2 | abdanan
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | ponta do sol
# Processing Record 18 of Set 2 | tiksi
# Processing Record 19 of Set 2 | hobart
# Processing Record 20 of Set 2 | san quintin
# Processing Record 21 of Set 2 | vero beach
# Processing Record 22 of Set 2 | crotone
# Processing Record 23 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 24 of Set 2 | mazyr
# Processing Record 25 of Set 2 | herat
# Processing Record 26 of Set 2 | bengkulu
# Processing Record 27 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 28 of Set 2 | lebu
# Processing Record 29 of Set 2 | nargana
# Processing Record 30 of Set 2 | jharsuguda
# Processing Record 31 of Set 2 | torbay
# Processing Record 32 of Set 2 | georgetown
# Processing Record 33 of Set 2 | oranjemund
# Processing Record 34 of Set 2 | hermanus
# Processing Record 35 of Set 2 | rikitea
# Processing Record 36 of Set 2 | geraldton
# Processing Record 37 of Set 2 | namibe
# Processing Record 38 of Set 2 | shurugwi
# Processing Record 39 of Set 2 | ballina
# Processing Record 40 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 2 | maghama
# City not found. Skipping...
# Processing Record 42 of Set 2 | george town
# Processing Record 43 of Set 2 | custoias
# Processing Record 44 of Set 2 | kaitangata
# Processing Record 45 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 47 of Set 2 | saint george
# Processing Record 48 of Set 2 | puerto ayora
# Processing Record 49 of Set 2 | noumea
# Processing Record 50 of Set 2 | ribeira grande
# Processing Record 1 of Set 3 | arraial do cabo
# Processing Record 2 of Set 3 | fethiye
# Processing Record 3 of Set 3 | nikolskoye
# Processing Record 4 of Set 3 | aleksandrov gay
# Processing Record 5 of Set 3 | axim
# Processing Record 6 of Set 3 | zhuanghe
# Processing Record 7 of Set 3 | mengcheng
# Processing Record 8 of Set 3 | nouadhibou
# Processing Record 9 of Set 3 | cabo san lucas
# Processing Record 10 of Set 3 | mount gambier
# Processing Record 11 of Set 3 | olustvere
# Processing Record 12 of Set 3 | hilo
# Processing Record 13 of Set 3 | spring hill
# Processing Record 14 of Set 3 | airai
# Processing Record 15 of Set 3 | hithadhoo
# Processing Record 16 of Set 3 | jackson
# Processing Record 17 of Set 3 | dikson
# Processing Record 18 of Set 3 | cidreira
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 21 of Set 3 | norman wells
# Processing Record 22 of Set 3 | mayo
# Processing Record 23 of Set 3 | yar-sale
# Processing Record 24 of Set 3 | taltal
# Processing Record 25 of Set 3 | cape town
# Processing Record 26 of Set 3 | hoquiam
# Processing Record 27 of Set 3 | westpunt
# City not found. Skipping...
# Processing Record 28 of Set 3 | doha
# Processing Record 29 of Set 3 | ancud
# Processing Record 30 of Set 3 | tautira
# Processing Record 31 of Set 3 | mahaicony
# City not found. Skipping...
# Processing Record 32 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 33 of Set 3 | sipovo
# Processing Record 34 of Set 3 | porto walter
# Processing Record 35 of Set 3 | beloha
# Processing Record 36 of Set 3 | kysyl-syr
# Processing Record 37 of Set 3 | kalianget
# Processing Record 38 of Set 3 | mar del plata
# Processing Record 39 of Set 3 | saint-philippe
# Processing Record 40 of Set 3 | kurchum
# Processing Record 41 of Set 3 | chokurdakh
# Processing Record 42 of Set 3 | lavrentiya
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | kudahuvadhoo
# Processing Record 45 of Set 3 | kloulklubed
# Processing Record 46 of Set 3 | buraydah
# Processing Record 47 of Set 3 | kirakira
# Processing Record 48 of Set 3 | fortuna
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | usinsk
# Processing Record 1 of Set 4 | lalganj
# Processing Record 2 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 4 | kurilsk
# Processing Record 4 of Set 4 | palmer
# Processing Record 5 of Set 4 | siemiatycze
# Processing Record 6 of Set 4 | barcelos
# Processing Record 7 of Set 4 | placerville
# Processing Record 8 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 9 of Set 4 | den helder
# Processing Record 10 of Set 4 | karaul
# City not found. Skipping...
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | bredasdorp
# Processing Record 13 of Set 4 | hojslev
# Processing Record 14 of Set 4 | macaboboni
# City not found. Skipping...
# Processing Record 15 of Set 4 | pevek
# Processing Record 16 of Set 4 | naze
# Processing Record 17 of Set 4 | butaritari
# Processing Record 18 of Set 4 | havre-saint-pierre
# Processing Record 19 of Set 4 | kutum
# Processing Record 20 of Set 4 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 4 | victoria
# Processing Record 22 of Set 4 | tasiilaq
# Processing Record 23 of Set 4 | bethel
# Processing Record 24 of Set 4 | magadi
# Processing Record 25 of Set 4 | gander
# Processing Record 26 of Set 4 | ust-nera
# Processing Record 27 of Set 4 | tabou
# Processing Record 28 of Set 4 | ribas do rio pardo
# Processing Record 29 of Set 4 | portland
# Processing Record 30 of Set 4 | calabozo
# Processing Record 31 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 32 of Set 4 | tezu
# Processing Record 33 of Set 4 | kasongo
# Processing Record 34 of Set 4 | saint-ambroise
# Processing Record 35 of Set 4 | otavi
# Processing Record 36 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 37 of Set 4 | chulman
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | lompoc
# Processing Record 40 of Set 4 | kidal
# Processing Record 41 of Set 4 | achacachi
# Processing Record 42 of Set 4 | kaeo
# Processing Record 43 of Set 4 | llorente
# Processing Record 44 of Set 4 | payson
# Processing Record 45 of Set 4 | carutapera
# Processing Record 46 of Set 4 | provideniya
# Processing Record 47 of Set 4 | himora
# City not found. Skipping...
# Processing Record 48 of Set 4 | cherlak
# Processing Record 49 of Set 4 | kiverion
# City not found. Skipping...
# Processing Record 50 of Set 4 | uthal
# Processing Record 1 of Set 5 | verkh-usugli
# Processing Record 2 of Set 5 | clyde river
# Processing Record 3 of Set 5 | ust-tsilma
# Processing Record 4 of Set 5 | sola
# Processing Record 5 of Set 5 | carnarvon
# Processing Record 6 of Set 5 | berezovka
# Processing Record 7 of Set 5 | bida
# Processing Record 8 of Set 5 | makakilo city
# Processing Record 9 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 10 of Set 5 | itum-kale
# Processing Record 11 of Set 5 | cherskiy
# Processing Record 12 of Set 5 | pimentel
# Processing Record 13 of Set 5 | sistranda
# Processing Record 14 of Set 5 | port hedland
# Processing Record 15 of Set 5 | riom
# Processing Record 16 of Set 5 | wajid
# Processing Record 17 of Set 5 | karratha
# Processing Record 18 of Set 5 | toliary
# City not found. Skipping...
# Processing Record 19 of Set 5 | sao filipe
# Processing Record 20 of Set 5 | levokumskoye
# Processing Record 21 of Set 5 | tokur
# Processing Record 22 of Set 5 | ahipara
# Processing Record 23 of Set 5 | jutai
# Processing Record 24 of Set 5 | labytnangi
# Processing Record 25 of Set 5 | salalah
# Processing Record 26 of Set 5 | paka
# Processing Record 27 of Set 5 | dalmeny
# Processing Record 28 of Set 5 | mount isa
# Processing Record 29 of Set 5 | revda
# Processing Record 30 of Set 5 | piacabucu
# Processing Record 31 of Set 5 | esperance
# Processing Record 32 of Set 5 | tuatapere
# Processing Record 33 of Set 5 | labuhan
# Processing Record 34 of Set 5 | hearst
# Processing Record 35 of Set 5 | port keats
# Processing Record 36 of Set 5 | thompson
# Processing Record 37 of Set 5 | meulaboh
# Processing Record 38 of Set 5 | salamiyah
# Processing Record 39 of Set 5 | kuah
# Processing Record 40 of Set 5 | mehamn
# Processing Record 41 of Set 5 | lagoa
# Processing Record 42 of Set 5 | ashcroft
# Processing Record 43 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 5 | kavieng
# Processing Record 45 of Set 5 | kungurtug
# Processing Record 46 of Set 5 | oskarshamn
# Processing Record 47 of Set 5 | ravar
# Processing Record 48 of Set 5 | tupik
# Processing Record 49 of Set 5 | vardo
# Processing Record 50 of Set 5 | klaksvik
# Processing Record 1 of Set 6 | kasongo-lunda
# Processing Record 2 of Set 6 | cam ranh
# Processing Record 3 of Set 6 | vila
# Processing Record 4 of Set 6 | rio verde de mato grosso
# Processing Record 5 of Set 6 | kruisfontein
# Processing Record 6 of Set 6 | marsh harbour
# Processing Record 7 of Set 6 | leh
# Processing Record 8 of Set 6 | nam tha
# City not found. Skipping...
# Processing Record 9 of Set 6 | lorengau
# Processing Record 10 of Set 6 | mariinsk
# Processing Record 11 of Set 6 | niquelandia
# Processing Record 12 of Set 6 | coquimbo
# Processing Record 13 of Set 6 | iqaluit
# Processing Record 14 of Set 6 | mwinilunga
# Processing Record 15 of Set 6 | sorland
# Processing Record 16 of Set 6 | dom pedrito
# Processing Record 17 of Set 6 | kuching
# Processing Record 18 of Set 6 | pilar
# Processing Record 19 of Set 6 | hobbs
# Processing Record 20 of Set 6 | urucara
# Processing Record 21 of Set 6 | ullapool
# Processing Record 22 of Set 6 | qaanaaq
# Processing Record 23 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 6 | diamantino
# Processing Record 25 of Set 6 | chiang rai
# Processing Record 26 of Set 6 | aripuana
# Processing Record 27 of Set 6 | padang
# Processing Record 28 of Set 6 | san martin
# Processing Record 29 of Set 6 | muros
# Processing Record 30 of Set 6 | lipin bor
# Processing Record 31 of Set 6 | chapais
# Processing Record 32 of Set 6 | san carlos
# Processing Record 33 of Set 6 | aykhal
# Processing Record 34 of Set 6 | potosi
# Processing Record 35 of Set 6 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 6 | birin
# Processing Record 37 of Set 6 | kalang
# Processing Record 38 of Set 6 | olga
# Processing Record 39 of Set 6 | launceston
# Processing Record 40 of Set 6 | kibondo
# Processing Record 41 of Set 6 | kamenka
# Processing Record 42 of Set 6 | dawei
# Processing Record 43 of Set 6 | sahuaripa
# Processing Record 44 of Set 6 | san policarpo
# Processing Record 45 of Set 6 | yulara
# Processing Record 46 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 6 | kasempa
# Processing Record 48 of Set 6 | bahir dar
# Processing Record 49 of Set 6 | los llanos de aridane
# Processing Record 50 of Set 6 | zelenets
# Processing Record 1 of Set 7 | biak
# Processing Record 2 of Set 7 | lethem
# Processing Record 3 of Set 7 | oranjestad
# Processing Record 4 of Set 7 | champerico
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | gat
# Processing Record 7 of Set 7 | casma
# Processing Record 8 of Set 7 | gravdal
# Processing Record 9 of Set 7 | puerto del rosario
# Processing Record 10 of Set 7 | bambous virieux
# Processing Record 11 of Set 7 | emerald
# Processing Record 12 of Set 7 | imbituba
# Processing Record 13 of Set 7 | auki
# Processing Record 14 of Set 7 | constitucion
# Processing Record 15 of Set 7 | ostrovnoy
# Processing Record 16 of Set 7 | rosetta
# Processing Record 17 of Set 7 | erenhot
# Processing Record 18 of Set 7 | andenes
# Processing Record 19 of Set 7 | dabat
# Processing Record 20 of Set 7 | katsuura
# Processing Record 21 of Set 7 | sioux lookout
# Processing Record 22 of Set 7 | mezen
# Processing Record 23 of Set 7 | hurghada
# Processing Record 24 of Set 7 | fukue
# Processing Record 25 of Set 7 | sakaiminato
# Processing Record 26 of Set 7 | pangkalanbuun
# Processing Record 27 of Set 7 | nouakchott
# Processing Record 28 of Set 7 | balaguer
# Processing Record 29 of Set 7 | paros
# Processing Record 30 of Set 7 | prince rupert
# Processing Record 31 of Set 7 | sassandra
# Processing Record 32 of Set 7 | sungairaya
# Processing Record 33 of Set 7 | husavik
# Processing Record 34 of Set 7 | tibati
# Processing Record 35 of Set 7 | avera
# Processing Record 36 of Set 7 | las palmas
# Processing Record 37 of Set 7 | wamba
# Processing Record 38 of Set 7 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 7 | lloydminster
# Processing Record 40 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 41 of Set 7 | mnogovershinnyy
# Processing Record 42 of Set 7 | saldanha
# Processing Record 43 of Set 7 | port lincoln
# Processing Record 44 of Set 7 | hasaki
# Processing Record 45 of Set 7 | guane
# Processing Record 46 of Set 7 | theologos
# City not found. Skipping...
# Processing Record 47 of Set 7 | kegayli
# City not found. Skipping...
# Processing Record 48 of Set 7 | matara
# Processing Record 49 of Set 7 | crab hill
# City not found. Skipping...
# Processing Record 50 of Set 7 | haines junction
# Processing Record 1 of Set 8 | sinnamary
# Processing Record 2 of Set 8 | rungata
# City not found. Skipping...
# Processing Record 3 of Set 8 | presidencia roque saenz pena
# Processing Record 4 of Set 8 | balykshi
# Processing Record 5 of Set 8 | bowen
# Processing Record 6 of Set 8 | karlskrona
# Processing Record 7 of Set 8 | kosh-agach
# Processing Record 8 of Set 8 | margate
# Processing Record 9 of Set 8 | ilulissat
# Processing Record 10 of Set 8 | coihaique
# Processing Record 11 of Set 8 | tiznit
# Processing Record 12 of Set 8 | la macarena
# Processing Record 13 of Set 8 | burica
# City not found. Skipping...
# Processing Record 14 of Set 8 | kitgum
# Processing Record 15 of Set 8 | belle fourche
# Processing Record 16 of Set 8 | rovaniemi
# Processing Record 17 of Set 8 | nizhnyaya omka
# Processing Record 18 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 8 | ituni
# City not found. Skipping...
# Processing Record 20 of Set 8 | benguela
# Processing Record 21 of Set 8 | shakiso
# Processing Record 22 of Set 8 | vestmannaeyjar
# Processing Record 23 of Set 8 | vila velha
# Processing Record 24 of Set 8 | semnan
# Processing Record 25 of Set 8 | ijaki
# City not found. Skipping...
# Processing Record 26 of Set 8 | trinidad
# Processing Record 27 of Set 8 | ternate
# Processing Record 28 of Set 8 | yeppoon
# Processing Record 29 of Set 8 | jatiroto
# Processing Record 30 of Set 8 | sitka
# Processing Record 31 of Set 8 | rayong
# Processing Record 32 of Set 8 | san andres
# Processing Record 33 of Set 8 | banda aceh
# Processing Record 34 of Set 8 | dingli
# Processing Record 35 of Set 8 | kalmunai
# Processing Record 36 of Set 8 | faanui
# Processing Record 37 of Set 8 | la ronge
# Processing Record 38 of Set 8 | atbasar
# Processing Record 39 of Set 8 | nelipyno
# Processing Record 40 of Set 8 | paamiut
# Processing Record 41 of Set 8 | nacala
# Processing Record 42 of Set 8 | berlevag
# Processing Record 43 of Set 8 | hluti
# Processing Record 44 of Set 8 | souillac
# Processing Record 45 of Set 8 | alamogordo
# Processing Record 46 of Set 8 | kawana waters
# City not found. Skipping...
# Processing Record 47 of Set 8 | khartoum
# Processing Record 48 of Set 8 | balkanabat
# Processing Record 49 of Set 8 | soligalich
# Processing Record 50 of Set 8 | eyl
# Processing Record 1 of Set 9 | kawalu
# Processing Record 2 of Set 9 | camana
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | walvis bay
# Processing Record 5 of Set 9 | pangody
# Processing Record 6 of Set 9 | guerrero negro
# Processing Record 7 of Set 9 | quatre cocos
# Processing Record 8 of Set 9 | saint-gilles
# Processing Record 9 of Set 9 | hambantota
# Processing Record 10 of Set 9 | barpathar
# Processing Record 11 of Set 9 | pacific grove
# Processing Record 12 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 9 | mangrol
# Processing Record 14 of Set 9 | saint-georges
# Processing Record 15 of Set 9 | yiyang
# Processing Record 16 of Set 9 | yichang
# Processing Record 17 of Set 9 | tiarei
# Processing Record 18 of Set 9 | samagaltay
# Processing Record 19 of Set 9 | sabha
# Processing Record 20 of Set 9 | caravelas
# Processing Record 21 of Set 9 | giyani
# Processing Record 22 of Set 9 | chengde
# Processing Record 23 of Set 9 | olinda
# Processing Record 24 of Set 9 | kropotkin
# Processing Record 25 of Set 9 | sanming
# Processing Record 26 of Set 9 | taranagar
# Processing Record 27 of Set 9 | roald
# Processing Record 28 of Set 9 | saint-denis
# Processing Record 29 of Set 9 | atar
# Processing Record 30 of Set 9 | urucui
# Processing Record 31 of Set 9 | iracoubo
# Processing Record 32 of Set 9 | pangnirtung
# Processing Record 33 of Set 9 | kalomo
# City not found. Skipping...
# Processing Record 34 of Set 9 | ballarat
# Processing Record 35 of Set 9 | dingle
# Processing Record 36 of Set 9 | cayenne
# Processing Record 37 of Set 9 | poum
# Processing Record 38 of Set 9 | gillette
# Processing Record 39 of Set 9 | nebolchi
# Processing Record 40 of Set 9 | vite
# Processing Record 41 of Set 9 | ixtapa
# Processing Record 42 of Set 9 | isangel
# Processing Record 43 of Set 9 | kavaratti
# Processing Record 44 of Set 9 | el asintal
# Processing Record 45 of Set 9 | peleduy
# Processing Record 46 of Set 9 | hastings
# Processing Record 47 of Set 9 | monthey
# Processing Record 48 of Set 9 | shimoda
# Processing Record 49 of Set 9 | swan river
# Processing Record 50 of Set 9 | zinder
# Processing Record 1 of Set 10 | warangal
# Processing Record 2 of Set 10 | gao
# Processing Record 3 of Set 10 | urubamba
# Processing Record 4 of Set 10 | high rock
# Processing Record 5 of Set 10 | copiapo
# Processing Record 6 of Set 10 | ulaangom
# Processing Record 7 of Set 10 | beni
# Processing Record 8 of Set 10 | fuerte olimpo
# Processing Record 9 of Set 10 | vaitape
# Processing Record 10 of Set 10 | morant bay
# Processing Record 11 of Set 10 | mirzapur
# Processing Record 12 of Set 10 | smithers
# Processing Record 13 of Set 10 | west bay
# Processing Record 14 of Set 10 | balatonfured
# Processing Record 15 of Set 10 | lardos
# Processing Record 16 of Set 10 | wahiawa
# Processing Record 17 of Set 10 | tura
# Processing Record 18 of Set 10 | anaconda
# Processing Record 19 of Set 10 | finschhafen
# Processing Record 20 of Set 10 | dubbo
# Processing Record 21 of Set 10 | moose factory
# Processing Record 22 of Set 10 | winnemucca
# Processing Record 23 of Set 10 | medea
# Processing Record 24 of Set 10 | mgandu
# Processing Record 25 of Set 10 | shubarshi
# Processing Record 26 of Set 10 | bendigo
# Processing Record 27 of Set 10 | corner brook
# Processing Record 28 of Set 10 | lacey
# Processing Record 29 of Set 10 | havelock
# Processing Record 30 of Set 10 | tadine
# Processing Record 31 of Set 10 | vanimo
# Processing Record 32 of Set 10 | alofi
# Processing Record 33 of Set 10 | puerto escondido
# Processing Record 34 of Set 10 | dongsheng
# Processing Record 35 of Set 10 | nicoya
# Processing Record 36 of Set 10 | keshan
# City not found. Skipping...
# Processing Record 37 of Set 10 | maceio
# Processing Record 38 of Set 10 | kashan
# Processing Record 39 of Set 10 | labe
# Processing Record 40 of Set 10 | cururupu
# Processing Record 41 of Set 10 | naryan-mar
# Processing Record 42 of Set 10 | rongcheng
# Processing Record 43 of Set 10 | puerto madryn
# Processing Record 44 of Set 10 | fevralsk
# City not found. Skipping...
# Processing Record 45 of Set 10 | belmonte
# Processing Record 46 of Set 10 | praia da vitoria
# Processing Record 47 of Set 10 | folldal
# Processing Record 48 of Set 10 | kazachinskoye
# Processing Record 49 of Set 10 | fuling
# Processing Record 50 of Set 10 | maniitsoq
# Processing Record 1 of Set 11 | nantucket
# Processing Record 2 of Set 11 | beaupre
# Processing Record 3 of Set 11 | sena madureira
# Processing Record 4 of Set 11 | stodolishche
# Processing Record 5 of Set 11 | lapua
# Processing Record 6 of Set 11 | rudraprayag
# Processing Record 7 of Set 11 | altonia
# City not found. Skipping...
# Processing Record 8 of Set 11 | codrington
# Processing Record 9 of Set 11 | okhotsk
# Processing Record 10 of Set 11 | rio de janeiro
# Processing Record 11 of Set 11 | dukat
# Processing Record 12 of Set 11 | kununurra
# Processing Record 13 of Set 11 | valdivia
# Processing Record 14 of Set 11 | qeshm
# Processing Record 15 of Set 11 | birnin kebbi
# Processing Record 16 of Set 11 | tari
# Processing Record 17 of Set 11 | sao jose de piranhas
# Processing Record 18 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 19 of Set 11 | flin flon
# Processing Record 20 of Set 11 | nikki
# Processing Record 21 of Set 11 | linjiang
# Processing Record 22 of Set 11 | valkeala
# Processing Record 23 of Set 11 | half moon bay
# Processing Record 24 of Set 11 | rapar
# Processing Record 25 of Set 11 | gazanjyk
# Processing Record 26 of Set 11 | itaqui
# Processing Record 27 of Set 11 | gotsu
# Processing Record 28 of Set 11 | fort nelson
# Processing Record 29 of Set 11 | acuna
# City not found. Skipping...
# Processing Record 30 of Set 11 | masterton
# Processing Record 31 of Set 11 | vysokogornyy
# Processing Record 32 of Set 11 | namatanai
# Processing Record 33 of Set 11 | marsaxlokk
# Processing Record 34 of Set 11 | alta gracia
# Processing Record 35 of Set 11 | neepawa
# Processing Record 36 of Set 11 | nador
# Processing Record 37 of Set 11 | araouane
# Processing Record 38 of Set 11 | luderitz
# Processing Record 39 of Set 11 | beringovskiy
# Processing Record 40 of Set 11 | mogadishu
# Processing Record 41 of Set 11 | sampit
# Processing Record 42 of Set 11 | sur
# Processing Record 43 of Set 11 | san carlos de bariloche
# Processing Record 44 of Set 11 | mumford
# Processing Record 45 of Set 11 | yirol
# City not found. Skipping...
# Processing Record 46 of Set 11 | burkburnett
# Processing Record 47 of Set 11 | hun
# Processing Record 48 of Set 11 | marawi
# Processing Record 49 of Set 11 | kenora
# Processing Record 50 of Set 11 | sioux falls
# Processing Record 1 of Set 12 | rio grande
# Processing Record 2 of Set 12 | dhidhdhoo
# Processing Record 3 of Set 12 | tarauaca
# Processing Record 4 of Set 12 | primalkinskoye
# Processing Record 5 of Set 12 | spearfish
# Processing Record 6 of Set 12 | salinopolis
# Processing Record 7 of Set 12 | rajshahi
# Processing Record 8 of Set 12 | ketchikan
# Processing Record 9 of Set 12 | chulym
# Processing Record 10 of Set 12 | mecca
# Processing Record 11 of Set 12 | abu samrah
# Processing Record 12 of Set 12 | la romana
# Processing Record 13 of Set 12 | verkhnyaya inta
# Processing Record 14 of Set 12 | korem
# Processing Record 15 of Set 12 | peque
# Processing Record 16 of Set 12 | aswan
# Processing Record 17 of Set 12 | mayya
# Processing Record 18 of Set 12 | seoul
# Processing Record 19 of Set 12 | clarence town
# Processing Record 20 of Set 12 | murchison
# Processing Record 21 of Set 12 | krupina
# Processing Record 22 of Set 12 | sento se
# City not found. Skipping...
# Processing Record 23 of Set 12 | thinadhoo
# Processing Record 24 of Set 12 | kaili
# Processing Record 25 of Set 12 | luanda
# Processing Record 26 of Set 12 | hofn
# Processing Record 27 of Set 12 | wanaka
# Processing Record 28 of Set 12 | nizwa
# Processing Record 29 of Set 12 | wukari
# Processing Record 30 of Set 12 | manthani
# Processing Record 31 of Set 12 | chimore
# Processing Record 32 of Set 12 | talnakh
# Processing Record 33 of Set 12 | elko
# Processing Record 34 of Set 12 | dunedin
# Processing Record 35 of Set 12 | aviles
# Processing Record 36 of Set 12 | ajdabiya
# Processing Record 37 of Set 12 | bend
# Processing Record 38 of Set 12 | tommot
# Processing Record 39 of Set 12 | gamba
# Processing Record 40 of Set 12 | guanare
# Processing Record 41 of Set 12 | floro
# Processing Record 42 of Set 12 | westport
# Processing Record 43 of Set 12 | antsohihy
# Processing Record 44 of Set 12 | ayagoz
# Processing Record 45 of Set 12 | sisimiut
# Processing Record 46 of Set 12 | channel-port aux basques
# Processing Record 47 of Set 12 | mbandaka
# Processing Record 48 of Set 12 | kibala
# Processing Record 49 of Set 12 | caceres
# Processing Record 50 of Set 12 | cape canaveral
# Processing Record 1 of Set 13 | geresk
# City not found. Skipping...
# Processing Record 2 of Set 13 | elesbao veloso
# Processing Record 3 of Set 13 | skjaerhollen
# City not found. Skipping...
# Processing Record 4 of Set 13 | kaiyuan
# Processing Record 5 of Set 13 | sumenep
# Processing Record 6 of Set 13 | yenagoa
# Processing Record 7 of Set 13 | kodinar
# Processing Record 8 of Set 13 | hervey bay
# Processing Record 9 of Set 13 | acajutla
# Processing Record 10 of Set 13 | xifeng
# Processing Record 11 of Set 13 | las vegas
# Processing Record 12 of Set 13 | aksu
# Processing Record 13 of Set 13 | springdale
# Processing Record 14 of Set 13 | gilgit
# Processing Record 15 of Set 13 | shieli
# Processing Record 16 of Set 13 | ampanihy
# Processing Record 17 of Set 13 | gladstone
# Processing Record 18 of Set 13 | lanigan
# Processing Record 19 of Set 13 | tsalka
# Processing Record 20 of Set 13 | lasa
# Processing Record 21 of Set 13 | martapura
# Processing Record 22 of Set 13 | bajram curri
# Processing Record 23 of Set 13 | wewak
# Processing Record 24 of Set 13 | sao joao da barra
# Processing Record 25 of Set 13 | jumla
# Processing Record 26 of Set 13 | barra do garcas
# Processing Record 27 of Set 13 | ahumada
# City not found. Skipping...
# Processing Record 28 of Set 13 | lukhovka
# Processing Record 29 of Set 13 | anadyr
# Processing Record 30 of Set 13 | tahta
# Processing Record 31 of Set 13 | tessalit
# Processing Record 32 of Set 13 | mattawa
# Processing Record 33 of Set 13 | grindavik
# Processing Record 34 of Set 13 | kedougou
# Processing Record 35 of Set 13 | nyagan
# Processing Record 36 of Set 13 | ponta delgada
# Processing Record 37 of Set 13 | katherine
# Processing Record 38 of Set 13 | ibra
# Processing Record 39 of Set 13 | burnie
# Processing Record 40 of Set 13 | remerschen
# Processing Record 41 of Set 13 | banfora
# Processing Record 42 of Set 13 | qaqortoq
# Processing Record 43 of Set 13 | sindou
# Processing Record 44 of Set 13 | ambon
# Processing Record 45 of Set 13 | slevik
# City not found. Skipping...
# Processing Record 46 of Set 13 | hualmay
# Processing Record 47 of Set 13 | camabatela
# Processing Record 48 of Set 13 | campos
# Processing Record 49 of Set 13 | tabas
# Processing Record 50 of Set 13 | dombas
# Processing Record 1 of Set 14 | samana
# Processing Record 2 of Set 14 | camacha
# Processing Record 3 of Set 14 | balabac
# Processing Record 4 of Set 14 | grudziadz
# Processing Record 5 of Set 14 | sofiysk
# City not found. Skipping...
# Processing Record 6 of Set 14 | kirkwood
# Processing Record 7 of Set 14 | necochea
# Processing Record 8 of Set 14 | zelenoborsk
# Processing Record 9 of Set 14 | keita
# Processing Record 10 of Set 14 | severomuysk
# Processing Record 11 of Set 14 | zhigansk
# Processing Record 12 of Set 14 | severnyy
# Processing Record 13 of Set 14 | eydhafushi
# Processing Record 14 of Set 14 | am timan
# Processing Record 15 of Set 14 | rocha
# Processing Record 16 of Set 14 | weiser
# Processing Record 17 of Set 14 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 14 | wabana
# Processing Record 19 of Set 14 | kaihua
# Processing Record 20 of Set 14 | richards bay
# Processing Record 21 of Set 14 | quarai
# Processing Record 22 of Set 14 | winslow
# Processing Record 23 of Set 14 | verkhniy fiagdon
# Processing Record 24 of Set 14 | san patricio
# Processing Record 25 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 26 of Set 14 | monticello
# Processing Record 27 of Set 14 | llangefni
# Processing Record 28 of Set 14 | kita
# Processing Record 29 of Set 14 | havoysund
# Processing Record 30 of Set 14 | olbia
# Processing Record 31 of Set 14 | ormond beach
# Processing Record 32 of Set 14 | bilma
# Processing Record 33 of Set 14 | mastic beach
# Processing Record 34 of Set 14 | ormara
# Processing Record 35 of Set 14 | broken hill
# Processing Record 36 of Set 14 | ondorhaan
# City not found. Skipping...
# Processing Record 37 of Set 14 | abalak
# Processing Record 38 of Set 14 | malakal
# Processing Record 39 of Set 14 | svetlyy
# Processing Record 40 of Set 14 | nalhati
# Processing Record 41 of Set 14 | nerchinskiy zavod
# Processing Record 42 of Set 14 | vostok
# Processing Record 43 of Set 14 | chail
# Processing Record 44 of Set 14 | shahreza
# Processing Record 45 of Set 14 | loznica
# Processing Record 46 of Set 14 | tambura
# Processing Record 47 of Set 14 | valparaiso
# Processing Record 48 of Set 14 | ridgecrest
# Processing Record 49 of Set 14 | praia
# Processing Record 50 of Set 14 | palana
# Processing Record 1 of Set 15 | tongzi
# Processing Record 2 of Set 15 | nanortalik
# Processing Record 3 of Set 15 | shingu
# Processing Record 4 of Set 15 | waipawa
# Processing Record 5 of Set 15 | plettenberg bay
# Processing Record 6 of Set 15 | todos santos
# Processing Record 7 of Set 15 | corvallis
# Processing Record 8 of Set 15 | caramay
# Processing Record 9 of Set 15 | atkinson
# Processing Record 10 of Set 15 | hami
# Processing Record 11 of Set 15 | vilhena
# Processing Record 12 of Set 15 | zunyi
# Processing Record 13 of Set 15 | aasiaat
# Processing Record 14 of Set 15 | sarangani
# Processing Record 15 of Set 15 | boa vista
# Processing Record 16 of Set 15 | visnes
# Processing Record 17 of Set 15 | urcos
# Processing Record 18 of Set 15 | shirpur
# Processing Record 19 of Set 15 | matay
# Processing Record 20 of Set 15 | darhan
# Processing Record 21 of Set 15 | kjollefjord
# Processing Record 22 of Set 15 | hoopstad
# Processing Record 23 of Set 15 | hokitika
# Processing Record 24 of Set 15 | bambanglipuro
# Processing Record 25 of Set 15 | susanville
# Processing Record 26 of Set 15 | moose jaw
# Processing Record 27 of Set 15 | porto novo
# Processing Record 28 of Set 15 | hadejia
# Processing Record 29 of Set 15 | port hardy
# Processing Record 30 of Set 15 | kupang
# Processing Record 31 of Set 15 | huilong
# Processing Record 32 of Set 15 | duz
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.

city_data_df = pd.DataFrame(city_data)

city_data_df.head(10)
# Out:
#             City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saskylakh  71.9167  114.0833     50.77        47          59
# 1  Saint-Gaudens  43.0833    0.6667     62.02        84          48
# 2    Yellowknife  62.4560 -114.3525     64.92        52          40
# 3   General Roca -39.0333  -67.5833     39.61        64         100
# 4   Poplar Bluff  36.7570  -90.3929     82.13        79           0
# 5          Kapaa  22.0752 -159.3190     82.38        85          40
# 6        Kahului  20.8947 -156.4700     80.62        69          40
# 7       Udachnyy  66.4167  112.4000     82.45        24          48
# 8   Christchurch -43.5333  172.6333     48.90        74           3
# 9         Albany  42.6001  -73.9662     61.21        92         100
#
#    Wind Speed Country Current Description
# 0        7.11      RU       broken clouds
# 1        4.16      FR          light rain
# 2        3.44      CA    scattered clouds
# 3        8.41      AR     overcast clouds
# 4        0.00      US           clear sky
# 5       13.80      US    scattered clouds
# 6       19.57      US    scattered clouds
# 7        9.73      RU    scattered clouds
# 8        8.05      NZ           clear sky
# 9        1.99      US     overcast clouds

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity",
                    "Cloudiness", "Wind Speed", "Current Description"]

city_data_df = city_data_df[new_column_order]

city_data_df.head(10)
# Out:
#             City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Saskylakh      RU  71.9167  114.0833     50.77        47          59
# 1  Saint-Gaudens      FR  43.0833    0.6667     62.02        84          48
# 2    Yellowknife      CA  62.4560 -114.3525     64.92        52          40
# 3   General Roca      AR -39.0333  -67.5833     39.61        64         100
# 4   Poplar Bluff      US  36.7570  -90.3929     82.13        79           0
# 5          Kapaa      US  22.0752 -159.3190     82.38        85          40
# 6        Kahului      US  20.8947 -156.4700     80.62        69          40
# 7       Udachnyy      RU  66.4167  112.4000     82.45        24          48
# 8   Christchurch      NZ -43.5333  172.6333     48.90        74           3
# 9         Albany      US  42.6001  -73.9662     61.21        92         100
#
#    Wind Speed Current Description
# 0        7.11       broken clouds
# 1        4.16          light rain
# 2        3.44    scattered clouds
# 3        8.41     overcast clouds
# 4        0.00           clear sky
# 5       13.80    scattered clouds
# 6       19.57    scattered clouds
# 7        9.73    scattered clouds
# 8        8.05           clear sky
# 9        1.99     overcast clouds

# %%
# Create the output file (csv)

output_data_file = "C:/Users/Keeron/Documents/Rice University Data Anlyst Bootcamp/Challenges/Challenge 6/World_Weather_Analysis/Weather_Database/WeatherPy_Database.csv"

# Export the City_Data into a csv

city_data_df.to_csv(output_data_file, index_label="Weather_ID")
